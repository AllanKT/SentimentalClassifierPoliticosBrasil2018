# %%
import pandas as pd
import tensorflow as tf
import numpy as np

import re
import nltk
from nltk.corpus import stopwords 
from nltk.stem.lancaster import LancasterStemmer

# %%
data = pd.read_csv("Candidatos/Bolsonaro.csv")
data.head()
# Out:
#    Unnamed: 0  candidato                                               text
# 0           0  Bolsonaro  RT @Miltonneves: Falo como “sapo de fora”. Ess...
# 1           1  Bolsonaro  RT @cidadaodemal: Viva Nossa Senhora Aparecida...
# 2           2  Bolsonaro  RT @carloscezarcjr: Bolsonaro fica em 1° lugar...
# 3           3  Bolsonaro  RT @NaoInviabilize: não foi atacada, não foi a...
# 4           4  Bolsonaro  É isso aí, Brasil acima de tudo, Deus acima de...

# %%
def words_to_lower(data):
    return data.text.apply(lambda x: x.lower())

def remove_username(data):
    return data.text.apply(lambda x: re.sub(r'@[\w\.-]+','',x))

def remove_email(data):
    return data.text.apply(lambda x: re.sub(r'[\w\.-]+@[\w\.-]+','',x))

def remove_url(data):
    return data.text.apply(lambda x: re.sub(r'^https?:\/\/.*[\r\n]*','',x))

def remove_number(data):
    return data.text.apply(lambda x: re.sub(r'[0-9]','',x))

def remove_pontuation(data):
    return data.text.apply(lambda x: re.sub(r'[^a-zA-z\s]','',x))

def remove_repeated_character(data):
    return data.text.apply(lambda x: re.sub(r"(\w)\1*", r'\1', x))

def tokenizer(data):
    return data.text.apply(lambda x: nltk.word_tokenize(x))

def remove_stopword(data):
    stop_words = set(stopwords.words('english'))
    return data.text.apply(lambda x: [j for j in x if not j in stop_words])

def stemming(data):
    stem = LancasterStemmer()
    return data.text.apply(lambda x: [stem.stem(j) for j in x])

def concat(data):
    return data.text.apply(lambda x: " ".join(x))

# %%
data.text = words_to_lower(data)
data.text = remove_username(data)
data.text = remove_number(data)
data.text = remove_pontuation(data)
data.text = remove_repeated_character(data)
data.text = tokenizer(data)
data.text = remove_stopword(data)
#data.text = stemming(data)
data.text = concat(data)

# %%
data.head()
# Out:
#    Unnamed: 0  candidato                                               text
# 0           0  Bolsonaro  rt falo como sapo de fora esas invenes de ataq...
# 1           1  Bolsonaro  rt viva nosa senhora aparecida pastor chutou i...
# 2           2  Bolsonaro  rt bolsonaro fica em lugar com milhes de votos...
# 3           3  Bolsonaro  rt foi atacada foi agredida ia l nis atris tud...
# 4           4  Bolsonaro  iso brasil acima de tudo deus acima de todos b...

# %%
corpus = data.text

# %%
words = []
for text in corpus:
    for word in text.split(' '):
        words.append(word)

words = set(words)

# %%
words
# Out:
# {'desprezo',
#  'francesa',
#  'htpstcohkvblktqzi',
#  'vtima',
#  'htpstcobymubx',
#  'patifaria',
#  'sincero',
#  'hofman',
#  'acesores',
#  'triste',
#  'atacaram',
#  'forja',
#  'ap',
#  'placa',
#  'presidncia',
#  'informar',
#  'buro',
#  'htpstcojrostl',
#  'pegar',
#  'falava',
#  'histria',
#  'prof',
#  'comprova',
#  'htpstcoarzmfnqgx',
#  'fechamento',
#  'nam',
#  'encontrlo',
#  'htpstcounlcoryp',
#  'exce',
#  'fodas',
#  'apoiaram',
#  'ofend',
#  'outro',
#  'ri',
#  'insta',
#  'gustavo',
#  'wylys',
#  'incentivo',
#  'htpstcosezesvtra',
#  'agredido',
#  'bloquear',
#  'influenciadores',
#  'nazifascistas',
#  'htpstcojnkzamvfera',
#  'dito',
#  'privatizad',
#  'exorcismo',
#  'cago',
#  'ajudou',
#  'aumentou',
#  'xinga',
#  'pesquisar',
#  'nega',
#  'bomes',
#  'gostava',
#  'tute',
#  'declara',
#  'pora',
#  'familia',
#  'podem',
#  'ufrj',
#  'htpstcoguxrfklq',
#  'prncipe',
#  'te',
#  'jos',
#  'tentativa',
#  'fala',
#  'cuspidor',
#  'mato',
#  'achando',
#  'gay',
#  'viva',
#  'sistema',
#  'volta',
#  'preconceituoso',
#  'eduardo',
#  'financeiro',
#  'barbaridades',
#  'certo',
#  'letras',
#  'ns',
#  'mentor',
#  'htpstcomayqteumy',
#  'htpstcowemkigr',
#  'alerta',
#  'preso',
#  'favelados',
#  'horor',
#  'valeu',
#  'rabe',
#  'htpstcospziqte',
#  'prpria',
#  'pele',
#  'homo',
#  'balanando',
#  'acreditar',
#  'aprendeu',
#  'vermelha',
#  'criou',
#  'urgncia',
#  'por',
#  'campanh',
#  'maranho',
#  'debata',
#  'deputados',
#  'rouanet',
#  'responsveis',
#  'suspeio',
#  'declarou',
#  'nmer',
#  'cadastradas',
#  'htpstcozrbexygwp',
#  'grupos',
#  'oriente',
#  'htpstcocrljxco',
#  'juza',
#  'responder',
#  'familiares',
#  'pslpr',
#  'revoltados',
#  'fraude',
#  'manuela',
#  'bol',
#  'meu',
#  'mario',
#  'crianas',
#  'convidar',
#  'realmente',
#  'eua',
#  'direito',
#  'que',
#  'brasileiros',
#  'bote',
#  'proteger',
#  'panteras',
#  'minas',
#  'fernando',
#  'serve',
#  'debatidas',
#  'htpstcolrmxtjvg',
#  'htpstconehtrcdtb',
#  'incitar',
#  'dirio',
#  'seguida',
#  'conheo',
#  'viver',
#  'cotas',
#  'apelido',
#  'puta',
#  'apanhando',
#  'lula',
#  'citada',
#  'htpstcohkmvxhpjf',
#  'eae',
#  'ascenso',
#  'esprito',
#  'apoiadora',
#  'merval',
#  'insinua',
#  'invaso',
#  'alckmin',
#  'qualquer',
#  'htpstcogkqxoltu',
#  'segura',
#  'ensina',
#  'comunistas',
#  'restos',
#  'motorista',
#  'agreso',
#  'funcionrios',
#  'democraciasim',
#  'arumar',
#  'reduzir',
#  'bate',
#  'produtora',
#  'externas',
#  'faca',
#  'estoucombols',
#  'relator',
#  'muda',
#  'idealizao',
#  'publicao',
#  'regininha',
#  'escolar',
#  'htpstcoayzjtuwqco',
#  'aborto',
#  'rio',
#  'htpstcovofosk',
#  'ht',
#  'varias',
#  'saia',
#  'atrs',
#  'htpstcozjgqomdv',
#  'esforo',
#  'ater',
#  'foz',
#  'quero',
#  'base',
#  'eleitoral',
#  'escolheu',
#  'mtico',
#  'homofbico',
#  'cumprir',
#  'menor',
#  'catlica',
#  'calnias',
#  'lgbts',
#  'qaeda',
#  'enquanto',
#  'anotem',
#  'homofobia',
#  'adicionei',
#  'branda',
#  'crists',
#  'tivese',
#  'htpstcoqjyfksli',
#  'latino',
#  'destinou',
#  'htpstcotnmprgr',
#  'teve',
#  'feia',
#  'longas',
#  'safadeza',
#  'negros',
#  'bastidores',
#  'htp',
#  'hezbolah',
#  'desistiram',
#  'falsas',
#  'vaiado',
#  'ajudar',
#  'mesias',
#  'sangue',
#  'ofendem',
#  'vencer',
#  'esto',
#  'fv',
#  'sente',
#  'polticas',
#  'querer',
#  'vitoriosa',
#  'fraco',
#  'longo',
#  'condies',
#  'aparece',
#  'curta',
#  'acontecendo',
#  'gravou',
#  'infinitamente',
#  'aliana',
#  'universidade',
#  'manipulao',
#  'chamar',
#  'htpstcozsmzmwht',
#  'htpstcoyhesukvbet',
#  'falsidad',
#  'defendeu',
#  'ouvir',
#  'baixou',
#  'htpstcotnzeilqfr',
#  'marcel',
#  'htpstcoitrwtvf',
#  'prev',
#  'boas',
#  'pichao',
#  'mauricio',
#  'devoto',
#  'htpstcozrvtalefh',
#  'amarelando',
#  'anlise',
#  'banido',
#  'uns',
#  'motivos',
#  'ofendendo',
#  'teria',
#  'vestia',
#  'afinal',
#  'bar',
#  'liked',
#  'minhas',
#  'subjugar',
#  'parlamentares',
#  'sinal',
#  'htpstcongujzpny',
#  'maquinetas',
#  'revela',
#  'ah',
#  'comunho',
#  'eses',
#  'noite',
#  'direita',
#  'mercado',
#  'misgino',
#  'htpstcodeafma',
#  'balada',
#  'htpstcordsmzroxs',
#  'prol',
#  'espalhadas',
#  'bancada',
#  'htpstcoyukpactd',
#  'apelando',
#  'nmero',
#  'solicitar',
#  'seja',
#  'htpstcozkqlqmnaq',
#  'moa',
#  'manifestaes',
#  'nazis',
#  'arquivado',
#  'repete',
#  'ou',
#  'primeiros',
#  'prpt',
#  'algum',
#  'derotou',
#  'imagem',
#  'militantes',
#  'postura',
#  'ele',
#  'barlo',
#  'diretamente',
#  'asumir',
#  'gigantes',
#  'registro',
#  'repercuso',
#  'duro',
#  'gt',
#  'tava',
#  'htpstcojoqimck',
#  'mintam',
#  'baseado',
#  'logo',
#  'superou',
#  'devem',
#  'incitaram',
#  'htpstcoifhknwlt',
#  'santa',
#  'perguntas',
#  'controlar',
#  'cu',
#  'provar',
#  'condenado',
#  'liberalismo',
#  'htpstcot',
#  'ulstra',
#  'fujam',
#  'derubou',
#  'partidrio',
#  'htpstcoegcgdie',
#  'esquadres',
#  'ansiedade',
#  'htpstcoijdkpbu',
#  'tema',
#  'internacional',
#  'extremista',
#  'pos',
#  'piada',
#  'htpstcoulysdskuk',
#  'helena',
#  'sera',
#  'contedo',
#  'htpstcoquhgkighj',
#  'feministas',
#  'anunciar',
#  'futuro',
#  'sofre',
#  'prometeu',
#  'preciso',
#  'veja',
#  'entendam',
#  'dio',
#  'degradao',
#  'htpstcoytaixcugv',
#  'obrigada',
#  'oi',
#  'htpstcoxypspjegq',
#  'post',
#  'argemiro',
#  'cearense',
#  'rt',
#  'pela',
#  'seria',
#  'matria',
#  'reforma',
#  'top',
#  'agresor',
#  'galera',
#  'nem',
#  'leandro',
#  'lixo',
#  'federal',
#  'htpstcobklvintl',
#  'recebeu',
#  'gosta',
#  'enxurada',
#  'ocupao',
#  'chamado',
#  'numero',
#  'discordncias',
#  'diseram',
#  'cristos',
#  'atores',
#  'ler',
#  'rs',
#  'culpa',
#  'tomam',
#  'motivo',
#  'perceber',
#  'levava',
#  'psimo',
#  'negocio',
#  'minutos',
#  'gerais',
#  'nese',
#  'vem',
#  'role',
#  'civilizatrioele',
#  'htpstcopuoc',
#  'apareceu',
#  'htpstcozfryepmci',
#  'fukuyama',
#  'acha',
#  'mentiras',
#  'canas',
#  'ambienta',
#  'bonosauro',
#  'htpstcojveptynp',
#  'registrado',
#  'pq',
#  'tem',
#  'est',
#  'func',
#  'tanta',
#  'ultraje',
#  'bandeirantes',
#  'polmica',
#  'praia',
#  'htpstcojnopfonfvo',
#  'piru',
#  'agresivo',
#  'senhor',
#  'new',
#  'elegeu',
#  'isto',
#  'dedinho',
#  'dia',
#  'colocar',
#  'resolvi',
#  'foto',
#  'circule',
#  'pedindo',
#  'htpstcodbyxjnaxmqfera',
#  'revistas',
#  'ameas',
#  'dantesco',
#  'retuitando',
#  'punida',
#  'juntos',
#  'olha',
#  'deparo',
#  'movimento',
#  'fico',
#  'esta',
#  'blocks',
#  'waldvogel',
#  'tentam',
#  'admite',
#  'usando',
#  'candidatu',
#  'emprender',
#  'candidatura',
#  'curtindo',
#  'gostei',
#  'este',
#  'conhecemos',
#  'direcionam',
#  'joga',
#  'gra',
#  'tuitando',
#  'bero',
#  'extremadireita',
#  'fazermos',
#  'htpstcoiuegsiugm',
#  'humanas',
#  'termina',
#  'pouquinho',
#  'votando',
#  'hadad',
#  'nogu',
#  'grava',
#  'boicotar',
#  'tnc',
#  'sustica',
#  'manca',
#  'tucano',
#  'escrita',
#  'pensam',
#  'pretende',
#  'ningum',
#  'documento',
#  'chegaram',
#  'fcil',
#  'incapaz',
#  'htpstcotir',
#  'br',
#  'caro',
#  'cultura',
#  'entanto',
#  'problema',
#  'votou',
#  'levantando',
#  'atendimento',
#  'promesa',
#  'atacar',
#  'ela',
#  'aps',
#  'numa',
#  'mec',
#  'onyx',
#  'htpstcoyngukfp',
#  'htpstconreojyorg',
#  'cmica',
#  'mt',
#  'informao',
#  'governo',
#  'adivinha',
#  'caruagem',
#  'creio',
#  'catequizavam',
#  'desmente',
#  'nosa',
#  'coruptos',
#  'invs',
#  'amiga',
#  'fuma',
#  'temer',
#  'estude',
#  'demais',
#  'atestado',
#  'pastores',
#  'facebok',
#  'votar',
#  'danos',
#  'candidato',
#  'internet',
#  'armadas',
#  'namorado',
#  'tais',
#  'provel',
#  'po',
#  'crise',
#  'conto',
#  'atacando',
#  'vote',
#  'propostas',
#  'qu',
#  'vi',
#  'respeito',
#  'socialismo',
#  'estuprada',
#  'humanamente',
#  'htpstcoymebuqrk',
#  'racista',
#  'htpstcovtvgqguhv',
#  'toma',
#  'deus',
#  'repblica',
#  'jogar',
#  'aliados',
#  'stf',
#  'htpstcoidpirgywk',
#  'batem',
#  'lido',
#  'elas',
#  'estar',
#  'bolsa',
#  'htpstcovpv',
#  'duas',
#  'projeto',
#  'petrolina',
#  'gil',
#  'htpstcofruyk',
#  'profisional',
#  'sou',
#  'flagrado',
#  'htpstcogrvxmjwq',
#  'reafirmou',
#  'tempo',
#  'muito',
#  'ouvi',
#  'orgulho',
#  'amigo',
#  'defensor',
#  'gnt',
#  'violenta',
#  'conversar',
#  'participei',
#  'divulgou',
#  'indiretas',
#  'desmontar',
#  'dica',
#  'todynho',
#  'vrias',
#  'anular',
#  'palestra',
#  'globo',
#  'mortos',
#  'color',
#  'com',
#  'presidencivel',
#  'cqc',
#  'anjo',
#  'eita',
#  'presid',
#  'programa',
#  'ser',
#  'corupta',
#  'waters',
#  'htpstcopmvcd',
#  'gastos',
#  'witzel',
#  'bertoche',
#  'chegada',
#  'vermelho',
#  'delegado',
#  'psl',
#  'bernardo',
#  'acaba',
#  'comprado',
#  'revolta',
#  'capim',
#  'crime',
#  'htpstcoifefcdy',
#  'nesa',
#  'fontes',
#  'gran',
#  'ntido',
#  'pregado',
#  'casal',
#  'escreveu',
#  'h',
#  'fraquejada',
#  'desagradveis',
#  'vagabundo',
#  'audincias',
#  'van',
#  'val',
#  'mel',
#  'dutra',
#  'dise',
#  'obcecado',
#  'pisa',
#  'criticada',
#  'rihan',
#  'mundo',
#  'residncia',
#  'caralho',
#  'reas',
#  'momento',
#  'mulher',
#  'falar',
#  'contincia',
#  'ento',
#  'feminina',
#  'votam',
#  'cota',
#  'posam',
#  'mortes',
#  'bato',
#  'titio',
#  'fundamentalismo',
#  'envolvendo',
#  'costuma',
#  'despreparado',
#  'catlicos',
#  'estatais',
#  'canta',
#  'fazo',
#  'questo',
#  'disto',
#  'confirma',
#  'come',
#  'nordeste',
#  'priso',
#  'colunista',
#  'interferindo',
#  'incitando',
#  'subscreveram',
#  'direto',
#  'maneira',
#  'recado',
#  'chavez',
#  'apoiam',
#  'playlist',
#  'matou',
#  'rachando',
#  'fora',
#  'canalha',
#  'acham',
#  'recusado',
#  'morte',
#  'htpstcoyzskvhxk',
#  'cmara',
#  'dcada',
#  'hein',
#  'vociferar',
#  'oq',
#  'espalhaele',
#  'sapata',
#  'sorte',
#  'htpstcososhrc',
#  'apenas',
#  'sabino',
#  'deixar',
#  'parem',
#  'htpstconslwaud',
#  'maior',
#  'vlas',
#  'soros',
#  'petrobras',
#  'peo',
#  'htpstcoflwtc',
#  'trabalha',
#  'renunciaptqueocirovence',
#  'legitimando',
#  'famlia',
#  'acabando',
#  'molengas',
#  'urgente',
#  'uma',
#  'valor',
#  'apoiar',
#  'nenhuma',
#  'populaodia',
#  'postou',
#  'compartilhado',
#  'zapzap',
#  'olhe',
#  'cabra',
#  'morer',
#  'maravilha',
#  'esfaqueou',
#  'em',
#  'vey',
#  'asasina',
#  'distribua',
#  'htpstcoyzfqzfwhek',
#  'competindo',
#  'estarei',
#  'parasem',
#  'circulao',
#  'mandando',
#  'tribuna',
#  'venezuela',
#  'mandado',
#  'como',
#  'neutralidade',
#  'hadadlula',
#  'envie',
#  'ditadura',
#  'fdp',
#  'liberar',
#  'pedido',
#  'lgbt',
#  'grave',
#  'acusaes',
#  'admiro',
#  'negras',
#  'risco',
#  'recordtv',
#  'expert',
#  'desde',
#  'htpstc',
#  'unio',
#  'percebeu',
#  'htpstcoxkidbydfoj',
#  'fhc',
#  'htpstcohysltdcty',
#  'primo',
#  'jovens',
#  'twi',
#  'mudar',
#  'htpstcovgemcyju',
#  'continuar',
#  'ideali',
#  'mortais',
#  'intransponveis',
#  'plano',
#  'verdade',
#  'psiquitrico',
#  'eram',
#  'imperdvel',
#  'material',
#  'sem',
#  'htpstcovfqydpgx',
#  'prefeito',
#  'fo',
#  'quan',
#  'esquerda',
#  'juiz',
#  'deses',
#  'lance',
#  'hahahahahaha',
#  'tendo',
#  'htpstcokfgjewgvk',
#  'lembramse',
#  'votao',
#  'tu',
#  'algo',
#  'pacifista',
#  'confiar',
#  'htpstcodiecvkp',
#  'sai',
#  'leitura',
#  'diagnstico',
#  'peso',
#  'roubar',
#  'madona',
#  'todos',
#  'visitou',
#  'fundo',
#  'capito',
#  'maurcio',
#  'portal',
#  'pior',
#  'htpstcogsoeqpefd',
#  'htpstcoypbkyfdla',
#  'aos',
#  'profisiona',
#  'formalmente',
#  'dizer',
#  'atacarem',
#  'aceita',
#  'novamente',
#  'hatem',
#  'ausncia',
#  'histrias',
#  'criminosas',
#  'aqui',
#  'vou',
#  'surgiu',
#  'ruas',
#  'sergio',
#  'povo',
#  'tentavam',
#  'esquecem',
#  'poucos',
#  'minha',
#  'poema',
#  'mein',
#  'ajuda',
#  'mentira',
#  'eletrnicas',
#  'pai',
#  'ferenho',
#  'copia',
#  'expe',
#  'spc',
#  'ancio',
#  'vez',
#  'atos',
#  'norte',
#  'apoio',
#  'prova',
#  'opositores',
#  'logotipo',
#  'estudo',
#  'recebido',
#  'lucro',
#  'nada',
#  'chamando',
#  'propor',
#  'mbl',
#  'canalhice',
#  'tirar',
#  'htpstcojblgf',
#  'caras',
#  'htpstcosoudxyw',
#  'mandou',
#  'voltou',
#  'recentemente',
#  'umas',
#  'universal',
#  'pesquisa',
#  'soltou',
#  'htpstcowaorheyal',
#  'htpstcovcsyxmeu',
#  'feliz',
#  'chamam',
#  'suja',
#  'petistada',
#  'htpstcomvxlwzxsr',
#  'beijo',
#  'j',
#  'pede',
#  'cima',
#  'foro',
#  'ahaha',
#  'fosem',
#  'aceitem',
#  'extra',
#  'rolou',
#  'hoje',
#  'leis',
#  'retirados',
#  'n',
#  'luta',
#  'maiso',
#  'bolsonarismo',
#  'riscada',
#  'htpstcopcbxv',
#  'desa',
#  'adianta',
#  'margaret',
#  'sur',
#  'poupar',
#  'recebe',
#  'contar',
#  'charlatanismo',
#  'jesus',
#  'htpstcoqvqknqo',
#  'nordestinos',
#  'sofrimento',
#  'movi',
#  'estampadas',
#  'ambiente',
#  'atraso',
#  'coragem',
#  'da',
#  'whatsap',
#  'htpstcokhlefjqbcg',
#  'twet',
#  'roger',
#  'conseguiu',
#  'meio',
#  'trabalho',
#  'cortar',
#  'inacreditvel',
#  'altos',
#  'barulho',
#  'pasou',
#  'htpstcorlaqwzc',
#  'tenho',
#  'solues',
#  'papo',
#  'arependido',
#  'htpstcojqcwutqes',
#  'peido',
#  'nas',
#  'wtf',
#  'bo',
#  'biro',
#  'organizar',
#  'metendo',
#  'bandido',
#  'amor',
#  'corupto',
#  'falam',
#  'htpstcodftnyjtpgf',
#  'torturadocrucificado',
#  'aceitar',
#  'direitinho',
#  'bolson',
#  'htpstcogsdwiex',
#  'vena',
#  'cad',
#  'enforca',
#  'hipocrisia',
#  'minorias',
#  'ca',
#  'lutar',
#  'comear',
#  'htpstcoikdqknqoy',
#  'antagonista',
#  'htpstcotkxbatlh',
#  'htpstcowkpfgadc',
#  'pres',
#  'esque',
#  'ira',
#  'fez',
#  'elogia',
#  'ficam',
#  'igreja',
#  'bolso',
#  'futuros',
#  'vivo',
#  'retirar',
#  'reclamou',
#  'pariu',
#  'testa',
#  'htpstcojtlzjk',
#  'sim',
#  'entretan',
#  'fonte',
#  'eleies',
#  'cut',
#  'ask',
#  'manda',
#  'raciocnio',
#  'dias',
#  ...}

# %%
word2int = {}

for i,word in enumerate(words):
    word2int[word] = i

sentences = []
for sentence in corpus:
    sentences.append(sentence.split())
    
WINDOW_SIZE = 2

data = []
for sentence in sentences:
    for idx, word in enumerate(sentence):
        for neighbor in sentence[max(idx - WINDOW_SIZE, 0) : min(idx + WINDOW_SIZE, len(sentence)) + 1] : 
            if neighbor != word:
                data.append([word, neighbor])

# %%
data
# Out:
# [['rt', 'falo'],
#  ['rt', 'como'],
#  ['falo', 'rt'],
#  ['falo', 'como'],
#  ['falo', 'sapo'],
#  ['como', 'rt'],
#  ['como', 'falo'],
#  ['como', 'sapo'],
#  ['como', 'de'],
#  ['sapo', 'falo'],
#  ['sapo', 'como'],
#  ['sapo', 'de'],
#  ['sapo', 'fora'],
#  ['de', 'como'],
#  ['de', 'sapo'],
#  ['de', 'fora'],
#  ['de', 'esas'],
#  ['fora', 'sapo'],
#  ['fora', 'de'],
#  ['fora', 'esas'],
#  ['fora', 'invenes'],
#  ['esas', 'de'],
#  ['esas', 'fora'],
#  ['esas', 'invenes'],
#  ['esas', 'de'],
#  ['invenes', 'fora'],
#  ['invenes', 'esas'],
#  ['invenes', 'de'],
#  ['invenes', 'ataques'],
#  ['de', 'esas'],
#  ['de', 'invenes'],
#  ['de', 'ataques'],
#  ['de', 'por'],
#  ['ataques', 'invenes'],
#  ['ataques', 'de'],
#  ['ataques', 'por'],
#  ['ataques', 'parte'],
#  ['por', 'de'],
#  ['por', 'ataques'],
#  ['por', 'parte'],
#  ['por', 'pesoal'],
#  ['parte', 'ataques'],
#  ['parte', 'por'],
#  ['parte', 'pesoal'],
#  ['parte', 'prpt'],
#  ['pesoal', 'por'],
#  ['pesoal', 'parte'],
#  ['pesoal', 'prpt'],
#  ['pesoal', 'para'],
#  ['prpt', 'parte'],
#  ['prpt', 'pesoal'],
#  ['prpt', 'para'],
#  ['prpt', 'pintar'],
#  ['para', 'pesoal'],
#  ['para', 'prpt'],
#  ['para', 'pintar'],
#  ['para', 'esfaqueado'],
#  ['pintar', 'prpt'],
#  ['pintar', 'para'],
#  ['pintar', 'esfaqueado'],
#  ['pintar', 'bolsonaro'],
#  ['esfaqueado', 'para'],
#  ['esfaqueado', 'pintar'],
#  ['esfaqueado', 'bolsonaro'],
#  ['esfaqueado', 'como'],
#  ['bolsonaro', 'pintar'],
#  ['bolsonaro', 'esfaqueado'],
#  ['bolsonaro', 'como'],
#  ['bolsonaro', 'r'],
#  ['como', 'esfaqueado'],
#  ['como', 'bolsonaro'],
#  ['como', 'r'],
#  ['r', 'bolsonaro'],
#  ['r', 'como'],
#  ['rt', 'viva'],
#  ['rt', 'nosa'],
#  ['viva', 'rt'],
#  ['viva', 'nosa'],
#  ['viva', 'senhora'],
#  ['nosa', 'rt'],
#  ['nosa', 'viva'],
#  ['nosa', 'senhora'],
#  ['nosa', 'aparecida'],
#  ['senhora', 'viva'],
#  ['senhora', 'nosa'],
#  ['senhora', 'aparecida'],
#  ['senhora', 'pastor'],
#  ['aparecida', 'nosa'],
#  ['aparecida', 'senhora'],
#  ['aparecida', 'pastor'],
#  ['aparecida', 'chutou'],
#  ['pastor', 'senhora'],
#  ['pastor', 'aparecida'],
#  ['pastor', 'chutou'],
#  ['pastor', 'imagem'],
#  ['chutou', 'aparecida'],
#  ['chutou', 'pastor'],
#  ['chutou', 'imagem'],
#  ['chutou', 'da'],
#  ['imagem', 'pastor'],
#  ['imagem', 'chutou'],
#  ['imagem', 'da'],
#  ['imagem', 'santa'],
#  ['da', 'chutou'],
#  ['da', 'imagem'],
#  ['da', 'santa'],
#  ['da', 'e'],
#  ['santa', 'imagem'],
#  ['santa', 'da'],
#  ['santa', 'e'],
#  ['santa', 'causou'],
#  ['e', 'da'],
#  ['e', 'santa'],
#  ['e', 'causou'],
#  ['e', 'revolta'],
#  ['causou', 'santa'],
#  ['causou', 'e'],
#  ['causou', 'revolta'],
#  ['causou', 'pas'],
#  ['revolta', 'e'],
#  ['revolta', 'causou'],
#  ['revolta', 'pas'],
#  ['revolta', 'edir'],
#  ['pas', 'causou'],
#  ['pas', 'revolta'],
#  ['pas', 'edir'],
#  ['pas', 'macedo'],
#  ['edir', 'revolta'],
#  ['edir', 'pas'],
#  ['edir', 'macedo'],
#  ['edir', 'lder'],
#  ['macedo', 'pas'],
#  ['macedo', 'edir'],
#  ['macedo', 'lder'],
#  ['macedo', 'da'],
#  ['lder', 'edir'],
#  ['lder', 'macedo'],
#  ['lder', 'da'],
#  ['da', 'macedo'],
#  ['da', 'lder'],
#  ['rt', 'bolsonaro'],
#  ['rt', 'fica'],
#  ['bolsonaro', 'rt'],
#  ['bolsonaro', 'fica'],
#  ['bolsonaro', 'em'],
#  ['fica', 'rt'],
#  ['fica', 'bolsonaro'],
#  ['fica', 'em'],
#  ['fica', 'lugar'],
#  ['em', 'bolsonaro'],
#  ['em', 'fica'],
#  ['em', 'lugar'],
#  ['em', 'com'],
#  ['lugar', 'fica'],
#  ['lugar', 'em'],
#  ['lugar', 'com'],
#  ['lugar', 'milhes'],
#  ['com', 'em'],
#  ['com', 'lugar'],
#  ['com', 'milhes'],
#  ['com', 'de'],
#  ['milhes', 'lugar'],
#  ['milhes', 'com'],
#  ['milhes', 'de'],
#  ['milhes', 'votos'],
#  ['de', 'com'],
#  ['de', 'milhes'],
#  ['de', 'votos'],
#  ['de', 'na'],
#  ['votos', 'milhes'],
#  ['votos', 'de'],
#  ['votos', 'na'],
#  ['votos', 'frente'],
#  ['na', 'de'],
#  ['na', 'votos'],
#  ['na', 'frente'],
#  ['na', 'revoltados'],
#  ['frente', 'votos'],
#  ['frente', 'na'],
#  ['frente', 'revoltados'],
#  ['frente', 'com'],
#  ['revoltados', 'na'],
#  ['revoltados', 'frente'],
#  ['revoltados', 'com'],
#  ['revoltados', 'esa'],
#  ['com', 'frente'],
#  ['com', 'revoltados'],
#  ['com', 'esa'],
#  ['com', 'diferena'],
#  ['esa', 'revoltados'],
#  ['esa', 'com'],
#  ['esa', 'diferena'],
#  ['esa', 'os'],
#  ['diferena', 'com'],
#  ['diferena', 'esa'],
#  ['diferena', 'os'],
#  ['diferena', 'apoiadores'],
#  ['os', 'esa'],
#  ['os', 'diferena'],
#  ['os', 'apoiadores'],
#  ['os', 'de'],
#  ['apoiadores', 'diferena'],
#  ['apoiadores', 'os'],
#  ['apoiadores', 'de'],
#  ['apoiadores', 'bo'],
#  ['de', 'os'],
#  ['de', 'apoiadores'],
#  ['de', 'bo'],
#  ['bo', 'apoiadores'],
#  ['bo', 'de'],
#  ['rt', 'foi'],
#  ['rt', 'atacada'],
#  ['foi', 'rt'],
#  ['foi', 'atacada'],
#  ['atacada', 'rt'],
#  ['atacada', 'foi'],
#  ['atacada', 'foi'],
#  ['atacada', 'agredida'],
#  ['foi', 'atacada'],
#  ['foi', 'agredida'],
#  ['foi', 'ia'],
#  ['agredida', 'atacada'],
#  ['agredida', 'foi'],
#  ['agredida', 'ia'],
#  ['agredida', 'l'],
#  ['ia', 'foi'],
#  ['ia', 'agredida'],
#  ['ia', 'l'],
#  ['ia', 'nis'],
#  ['l', 'agredida'],
#  ['l', 'ia'],
#  ['l', 'nis'],
#  ['l', 'atris'],
#  ['nis', 'ia'],
#  ['nis', 'l'],
#  ['nis', 'atris'],
#  ['nis', 'tudo'],
#  ['atris', 'l'],
#  ['atris', 'nis'],
#  ['atris', 'tudo'],
#  ['atris', 'rinu'],
#  ['tudo', 'nis'],
#  ['tudo', 'atris'],
#  ['tudo', 'rinu'],
#  ['tudo', 'k'],
#  ['rinu', 'atris'],
#  ['rinu', 'tudo'],
#  ['rinu', 'k'],
#  ['rinu', 'htpstcoraxqsoka'],
#  ['k', 'tudo'],
#  ['k', 'rinu'],
#  ['k', 'htpstcoraxqsoka'],
#  ['htpstcoraxqsoka', 'rinu'],
#  ['htpstcoraxqsoka', 'k'],
#  ['iso', 'brasil'],
#  ['iso', 'acima'],
#  ['brasil', 'iso'],
#  ['brasil', 'acima'],
#  ['brasil', 'de'],
#  ['acima', 'iso'],
#  ['acima', 'brasil'],
#  ['acima', 'de'],
#  ['acima', 'tudo'],
#  ['de', 'brasil'],
#  ['de', 'acima'],
#  ['de', 'tudo'],
#  ['de', 'deus'],
#  ['tudo', 'acima'],
#  ['tudo', 'de'],
#  ['tudo', 'deus'],
#  ['tudo', 'acima'],
#  ['deus', 'de'],
#  ['deus', 'tudo'],
#  ['deus', 'acima'],
#  ['deus', 'de'],
#  ['acima', 'tudo'],
#  ['acima', 'deus'],
#  ['acima', 'de'],
#  ['acima', 'todos'],
#  ['de', 'deus'],
#  ['de', 'acima'],
#  ['de', 'todos'],
#  ['de', 'brasilcombolsonaro'],
#  ['todos', 'acima'],
#  ['todos', 'de'],
#  ['todos', 'brasilcombolsonaro'],
#  ['brasilcombolsonaro', 'de'],
#  ['brasilcombolsonaro', 'todos'],
#  ['rt', 'boulos'],
#  ['rt', 'amigo'],
#  ['boulos', 'rt'],
#  ['boulos', 'amigo'],
#  ['boulos', 'hadad'],
#  ['amigo', 'rt'],
#  ['amigo', 'boulos'],
#  ['amigo', 'hadad'],
#  ['amigo', 'incitando'],
#  ['hadad', 'boulos'],
#  ['hadad', 'amigo'],
#  ['hadad', 'incitando'],
#  ['hadad', 'uma'],
#  ['incitando', 'amigo'],
#  ['incitando', 'hadad'],
#  ['incitando', 'uma'],
#  ['incitando', 'multido'],
#  ['uma', 'hadad'],
#  ['uma', 'incitando'],
#  ['uma', 'multido'],
#  ['uma', 'invadir'],
#  ['multido', 'incitando'],
#  ['multido', 'uma'],
#  ['multido', 'invadir'],
#  ['multido', 'casa'],
#  ['invadir', 'uma'],
#  ['invadir', 'multido'],
#  ['invadir', 'casa'],
#  ['invadir', 'bolsonaro'],
#  ['casa', 'multido'],
#  ['casa', 'invadir'],
#  ['casa', 'bolsonaro'],
#  ['casa', 'que'],
#  ['bolsonaro', 'invadir'],
#  ['bolsonaro', 'casa'],
#  ['bolsonaro', 'que'],
#  ['bolsonaro', 'deus'],
#  ['que', 'casa'],
#  ['que', 'bolsonaro'],
#  ['que', 'deus'],
#  ['que', 'proteja'],
#  ['deus', 'bolsonaro'],
#  ['deus', 'que'],
#  ['deus', 'proteja'],
#  ['deus', 'capito'],
#  ['proteja', 'que'],
#  ['proteja', 'deus'],
#  ['proteja', 'capito'],
#  ['capito', 'deus'],
#  ['capito', 'proteja'],
#  ['se', 'vc'],
#  ['se', 'lese'],
#  ['vc', 'se'],
#  ['vc', 'lese'],
#  ['vc', 'plano'],
#  ['lese', 'se'],
#  ['lese', 'vc'],
#  ['lese', 'plano'],
#  ['lese', 'de'],
#  ['plano', 'vc'],
#  ['plano', 'lese'],
#  ['plano', 'de'],
#  ['plano', 'governo'],
#  ['de', 'lese'],
#  ['de', 'plano'],
#  ['de', 'governo'],
#  ['de', 'bolsonaro'],
#  ['governo', 'plano'],
#  ['governo', 'de'],
#  ['governo', 'bolsonaro'],
#  ['governo', 'teria'],
#  ['bolsonaro', 'de'],
#  ['bolsonaro', 'governo'],
#  ['bolsonaro', 'teria'],
#  ['bolsonaro', 'tanta'],
#  ['teria', 'governo'],
#  ['teria', 'bolsonaro'],
#  ['teria', 'tanta'],
#  ['teria', 'certeza'],
#  ['tanta', 'bolsonaro'],
#  ['tanta', 'teria'],
#  ['tanta', 'certeza'],
#  ['tanta', 'que'],
#  ['certeza', 'teria'],
#  ['certeza', 'tanta'],
#  ['certeza', 'que'],
#  ['certeza', 'teria'],
#  ['que', 'tanta'],
#  ['que', 'certeza'],
#  ['que', 'teria'],
#  ['que', 'comida'],
#  ['teria', 'certeza'],
#  ['teria', 'que'],
#  ['teria', 'comida'],
#  ['teria', 'htpstcosryrupyn'],
#  ['comida', 'que'],
#  ['comida', 'teria'],
#  ['comida', 'htpstcosryrupyn'],
#  ['htpstcosryrupyn', 'teria'],
#  ['htpstcosryrupyn', 'comida'],
#  ['rt', 'daqui'],
#  ['rt', 'cem'],
#  ['daqui', 'rt'],
#  ['daqui', 'cem'],
#  ['daqui', 'anos'],
#  ['cem', 'rt'],
#  ['cem', 'daqui'],
#  ['cem', 'anos'],
#  ['cem', 'vai'],
#  ['anos', 'daqui'],
#  ['anos', 'cem'],
#  ['anos', 'vai'],
#  ['anos', 'ter'],
#  ['vai', 'cem'],
#  ['vai', 'anos'],
#  ['vai', 'ter'],
#  ['vai', 'adolescente'],
#  ['ter', 'anos'],
#  ['ter', 'vai'],
#  ['ter', 'adolescente'],
#  ['ter', 'dizendo'],
#  ['adolescente', 'vai'],
#  ['adolescente', 'ter'],
#  ['adolescente', 'dizendo'],
#  ['adolescente', 'que'],
#  ['dizendo', 'ter'],
#  ['dizendo', 'adolescente'],
#  ['dizendo', 'que'],
#  ['dizendo', 'bolsonaro'],
#  ['que', 'adolescente'],
#  ['que', 'dizendo'],
#  ['que', 'bolsonaro'],
#  ['que', 'foi'],
#  ['bolsonaro', 'dizendo'],
#  ['bolsonaro', 'que'],
#  ['bolsonaro', 'foi'],
#  ['bolsonaro', 'de'],
#  ['foi', 'que'],
#  ['foi', 'bolsonaro'],
#  ['foi', 'de'],
#  ['foi', 'esquerda'],
#  ['de', 'bolsonaro'],
#  ['de', 'foi'],
#  ['de', 'esquerda'],
#  ['esquerda', 'foi'],
#  ['esquerda', 'de'],
#  ['rt', 'cara'],
#  ['rt', 'fica'],
#  ['cara', 'rt'],
#  ['cara', 'fica'],
#  ['cara', 'puto'],
#  ['fica', 'rt'],
#  ['fica', 'cara'],
#  ['fica', 'puto'],
#  ['fica', 'e'],
#  ['puto', 'cara'],
#  ['puto', 'fica'],
#  ['puto', 'e'],
#  ['puto', 'xinga'],
#  ['e', 'fica'],
#  ['e', 'puto'],
#  ['e', 'xinga'],
#  ['e', 'em'],
#  ['xinga', 'puto'],
#  ['xinga', 'e'],
#  ['xinga', 'em'],
#  ['xinga', 'latim'],
#  ['em', 'e'],
#  ['em', 'xinga'],
#  ['em', 'latim'],
#  ['em', 'mano'],
#  ['latim', 'xinga'],
#  ['latim', 'em'],
#  ['latim', 'mano'],
#  ['latim', 'htpstcogsdwiex'],
#  ['mano', 'em'],
#  ['mano', 'latim'],
#  ['mano', 'htpstcogsdwiex'],
#  ['htpstcogsdwiex', 'latim'],
#  ['htpstcogsdwiex', 'mano'],
#  ['rt', 'auto'],
#  ['rt', 'crio'],
#  ['auto', 'rt'],
#  ['auto', 'crio'],
#  ['auto', 'tem'],
#  ['crio', 'rt'],
#  ['crio', 'auto'],
#  ['crio', 'tem'],
#  ['crio', 'manifestao'],
#  ['tem', 'auto'],
#  ['tem', 'crio'],
#  ['tem', 'manifestao'],
#  ['tem', 'contra'],
#  ['manifestao', 'crio'],
#  ['manifestao', 'tem'],
#  ['manifestao', 'contra'],
#  ['manifestao', 'presidencivel'],
#  ['contra', 'tem'],
#  ['contra', 'manifestao'],
#  ['contra', 'presidencivel'],
#  ['contra', 'jair'],
#  ['presidencivel', 'manifestao'],
#  ['presidencivel', 'contra'],
#  ['presidencivel', 'jair'],
#  ['presidencivel', 'bolsonaro'],
#  ['jair', 'contra'],
#  ['jair', 'presidencivel'],
#  ['jair', 'bolsonaro'],
#  ['jair', 'htpstcocrljxco'],
#  ['bolsonaro', 'presidencivel'],
#  ['bolsonaro', 'jair'],
#  ['bolsonaro', 'htpstcocrljxco'],
#  ['htpstcocrljxco', 'jair'],
#  ['htpstcocrljxco', 'bolsonaro'],
#  ['rt', 'chega'],
#  ['rt', 'nunca'],
#  ['chega', 'rt'],
#  ['chega', 'nunca'],
#  ['chega', 'mais'],
#  ['nunca', 'rt'],
#  ['nunca', 'chega'],
#  ['nunca', 'mais'],
#  ['nunca', 'falo'],
#  ['mais', 'chega'],
#  ['mais', 'nunca'],
#  ['mais', 'falo'],
#  ['mais', 'bem'],
#  ['falo', 'nunca'],
#  ['falo', 'mais'],
#  ['falo', 'bem'],
#  ['falo', 'de'],
#  ['bem', 'mais'],
#  ['bem', 'falo'],
#  ['bem', 'de'],
#  ['bem', 'bolsonaro'],
#  ['de', 'falo'],
#  ['de', 'bem'],
#  ['de', 'bolsonaro'],
#  ['de', 'depois'],
#  ['bolsonaro', 'bem'],
#  ['bolsonaro', 'de'],
#  ['bolsonaro', 'depois'],
#  ['bolsonaro', 'disto'],
#  ['depois', 'de'],
#  ['depois', 'bolsonaro'],
#  ['depois', 'disto'],
#  ['depois', 'aqui'],
#  ['disto', 'bolsonaro'],
#  ['disto', 'depois'],
#  ['disto', 'aqui'],
#  ['disto', 'olhem'],
#  ['aqui', 'depois'],
#  ['aqui', 'disto'],
#  ['aqui', 'olhem'],
#  ['aqui', 'q'],
#  ['olhem', 'disto'],
#  ['olhem', 'aqui'],
#  ['olhem', 'q'],
#  ['olhem', 'ele'],
#  ['q', 'aqui'],
#  ['q', 'olhem'],
#  ['q', 'ele'],
#  ['q', 'fez'],
#  ['ele', 'olhem'],
#  ['ele', 'q'],
#  ['ele', 'fez'],
#  ['ele', 'com'],
#  ['fez', 'q'],
#  ['fez', 'ele'],
#  ['fez', 'com'],
#  ['fez', 'um'],
#  ['com', 'ele'],
#  ['com', 'fez'],
#  ['com', 'um'],
#  ['com', 'nordestino'],
#  ['um', 'fez'],
#  ['um', 'com'],
#  ['um', 'nordestino'],
#  ['um', 'nordeste'],
#  ['nordestino', 'com'],
#  ['nordestino', 'um'],
#  ['nordestino', 'nordeste'],
#  ['nordestino', 'nordesteco'],
#  ['nordeste', 'um'],
#  ['nordeste', 'nordestino'],
#  ['nordeste', 'nordesteco'],
#  ['nordesteco', 'nordestino'],
#  ['nordesteco', 'nordeste'],
#  ['bolsonaro', 'diz'],
#  ['bolsonaro', 'que'],
#  ['diz', 'bolsonaro'],
#  ['diz', 'que'],
#  ['diz', 'aceita'],
#  ['que', 'bolsonaro'],
#  ['que', 'diz'],
#  ['que', 'aceita'],
#  ['que', 'realizar'],
#  ['aceita', 'diz'],
#  ['aceita', 'que'],
#  ['aceita', 'realizar'],
#  ['aceita', 'debate'],
#  ['realizar', 'que'],
#  ['realizar', 'aceita'],
#  ['realizar', 'debate'],
#  ['realizar', 'com'],
#  ['debate', 'aceita'],
#  ['debate', 'realizar'],
#  ['debate', 'com'],
#  ['debate', 'hadad'],
#  ['com', 'realizar'],
#  ['com', 'debate'],
#  ['com', 'hadad'],
#  ['hadad', 'debate'],
#  ['hadad', 'com'],
#  ['hadad', 'com'],
#  ['hadad', 'condies'],
#  ['com', 'hadad'],
#  ['com', 'condies'],
#  ['com', 'htpstcoixrntkpa'],
#  ['condies', 'hadad'],
#  ['condies', 'com'],
#  ['condies', 'htpstcoixrntkpa'],
#  ['htpstcoixrntkpa', 'com'],
#  ['htpstcoixrntkpa', 'condies'],
#  ['rt', 'bolsonaro'],
#  ['rt', 'vai'],
#  ['bolsonaro', 'rt'],
#  ['bolsonaro', 'vai'],
#  ['bolsonaro', 'matar'],
#  ['vai', 'rt'],
#  ['vai', 'bolsonaro'],
#  ['vai', 'matar'],
#  ['vai', 'viado'],
#  ['matar', 'bolsonaro'],
#  ['matar', 'vai'],
#  ['matar', 'viado'],
#  ['matar', 'vai'],
#  ['viado', 'vai'],
#  ['viado', 'matar'],
#  ['viado', 'vai'],
#  ['viado', 'diminuir'],
#  ['vai', 'matar'],
#  ['vai', 'viado'],
#  ['vai', 'diminuir'],
#  ['vai', 'mulher'],
#  ['diminuir', 'viado'],
#  ['diminuir', 'vai'],
#  ['diminuir', 'mulher'],
#  ['diminuir', 'vai'],
#  ['mulher', 'vai'],
#  ['mulher', 'diminuir'],
#  ['mulher', 'vai'],
#  ['mulher', 'bater'],
#  ['vai', 'diminuir'],
#  ['vai', 'mulher'],
#  ['vai', 'bater'],
#  ['vai', 'em'],
#  ['bater', 'mulher'],
#  ['bater', 'vai'],
#  ['bater', 'em'],
#  ['bater', 'preto'],
#  ['em', 'vai'],
#  ['em', 'bater'],
#  ['em', 'preto'],
#  ['em', 'com'],
#  ['preto', 'bater'],
#  ['preto', 'em'],
#  ['preto', 'com'],
#  ['preto', 'prprias'],
#  ['com', 'em'],
#  ['com', 'preto'],
#  ['com', 'prprias'],
#  ['com', 'mos'],
#  ['prprias', 'preto'],
#  ['prprias', 'com'],
#  ['prprias', 'mos'],
#  ['prprias', 'mas'],
#  ['mos', 'com'],
#  ['mos', 'prprias'],
#  ['mos', 'mas'],
#  ['mos', 'discurso'],
#  ['mas', 'prprias'],
#  ['mas', 'mos'],
#  ['mas', 'discurso'],
#  ['mas', 'de'],
#  ['discurso', 'mos'],
#  ['discurso', 'mas'],
#  ['discurso', 'de'],
#  ['de', 'mas'],
#  ['de', 'discurso'],
#  ['rt', 'engrado'],
#  ['rt', 'n'],
#  ['engrado', 'rt'],
#  ['engrado', 'n'],
#  ['engrado', 'hadad'],
#  ['n', 'rt'],
#  ['n', 'engrado'],
#  ['n', 'hadad'],
#  ['n', 'quando'],
#  ['hadad', 'engrado'],
#  ['hadad', 'n'],
#  ['hadad', 'quando'],
#  ['hadad', 'bispo'],
#  ['quando', 'n'],
#  ['quando', 'hadad'],
#  ['quando', 'bispo'],
#  ['quando', 'edir'],
#  ['bispo', 'hadad'],
#  ['bispo', 'quando'],
#  ['bispo', 'edir'],
#  ['bispo', 'macedo'],
#  ['edir', 'quando'],
#  ['edir', 'bispo'],
#  ['edir', 'macedo'],
#  ['edir', 'apoiou'],
#  ['macedo', 'bispo'],
#  ['macedo', 'edir'],
#  ['macedo', 'apoiou'],
#  ['macedo', 'pt'],
#  ['apoiou', 'edir'],
#  ['apoiou', 'macedo'],
#  ['apoiou', 'pt'],
#  ['apoiou', 'voc'],
#  ['pt', 'macedo'],
#  ['pt', 'apoiou'],
#  ['pt', 'voc'],
#  ['pt', 'reclamou'],
#  ['voc', 'apoiou'],
#  ['voc', 'pt'],
#  ['voc', 'reclamou'],
#  ['voc', 'agora'],
#  ['reclamou', 'pt'],
#  ['reclamou', 'voc'],
#  ['reclamou', 'agora'],
#  ['reclamou', 'que'],
#  ['agora', 'voc'],
#  ['agora', 'reclamou'],
#  ['agora', 'que'],
#  ['agora', 'ele'],
#  ['que', 'reclamou'],
#  ['que', 'agora'],
#  ['que', 'ele'],
#  ['que', 'declara'],
#  ['ele', 'agora'],
#  ['ele', 'que'],
#  ['ele', 'declara'],
#  ['ele', 'apoio'],
#  ['declara', 'que'],
#  ['declara', 'ele'],
#  ['declara', 'apoio'],
#  ['declara', 'ao'],
#  ['apoio', 'ele'],
#  ['apoio', 'declara'],
#  ['apoio', 'ao'],
#  ['apoio', 'jair'],
#  ['ao', 'declara'],
#  ['ao', 'apoio'],
#  ['ao', 'jair'],
#  ['ao', 'bolsonaro'],
#  ['jair', 'apoio'],
#  ['jair', 'ao'],
#  ['jair', 'bolsonaro'],
#  ['bolsonaro', 'ao'],
#  ['bolsonaro', 'jair'],
#  ['rt', 'governo'],
#  ['rt', 'de'],
#  ['governo', 'rt'],
#  ['governo', 'de'],
#  ['governo', 'jair'],
#  ['de', 'rt'],
#  ['de', 'governo'],
#  ['de', 'jair'],
#  ['de', 'bolsonaro'],
#  ['jair', 'governo'],
#  ['jair', 'de'],
#  ['jair', 'bolsonaro'],
#  ['jair', 'homem'],
#  ['bolsonaro', 'de'],
#  ['bolsonaro', 'jair'],
#  ['bolsonaro', 'homem'],
#  ['bolsonaro', 'campo'],
#  ['homem', 'jair'],
#  ['homem', 'bolsonaro'],
#  ['homem', 'campo'],
#  ['homem', 'seja'],
#  ['campo', 'bolsonaro'],
#  ['campo', 'homem'],
#  ['campo', 'seja'],
#  ['campo', 'agronegcio'],
#  ['seja', 'homem'],
#  ['seja', 'campo'],
#  ['seja', 'agronegcio'],
#  ['seja', 'ou'],
#  ['agronegcio', 'campo'],
#  ['agronegcio', 'seja'],
#  ['agronegcio', 'ou'],
#  ['agronegcio', 'da'],
#  ['ou', 'seja'],
#  ['ou', 'agronegcio'],
#  ['ou', 'da'],
#  ['ou', 'agricultura'],
#  ['da', 'agronegcio'],
#  ['da', 'ou'],
#  ['da', 'agricultura'],
#  ['da', 'familiar'],
#  ['agricultura', 'ou'],
#  ['agricultura', 'da'],
#  ['agricultura', 'familiar'],
#  ['agricultura', 'ser'],
#  ['familiar', 'da'],
#  ['familiar', 'agricultura'],
#  ['familiar', 'ser'],
#  ['familiar', 'valorizado'],
#  ['ser', 'agricultura'],
#  ['ser', 'familiar'],
#  ['ser', 'valorizado'],
#  ['ser', 'bolsonaro'],
#  ['valorizado', 'familiar'],
#  ['valorizado', 'ser'],
#  ['valorizado', 'bolsonaro'],
#  ['bolsonaro', 'ser'],
#  ['bolsonaro', 'valorizado'],
#  ['rt', 'sobre'],
#  ['rt', 'deputado'],
#  ['sobre', 'rt'],
#  ['sobre', 'deputado'],
#  ['sobre', 'jair'],
#  ['deputado', 'rt'],
#  ['deputado', 'sobre'],
#  ['deputado', 'jair'],
#  ['deputado', 'bolsonaro'],
#  ['jair', 'sobre'],
#  ['jair', 'deputado'],
#  ['jair', 'bolsonaro'],
#  ['jair', 'quem'],
#  ['bolsonaro', 'deputado'],
#  ['bolsonaro', 'jair'],
#  ['bolsonaro', 'quem'],
#  ['bolsonaro', 'tem'],
#  ['quem', 'jair'],
#  ['quem', 'bolsonaro'],
#  ['quem', 'tem'],
#  ['quem', 'proposta'],
#  ['tem', 'bolsonaro'],
#  ['tem', 'quem'],
#  ['tem', 'proposta'],
#  ['proposta', 'quem'],
#  ['proposta', 'tem'],
#  ['proposta', 'tem'],
#  ['proposta', 'que'],
#  ['tem', 'proposta'],
#  ['tem', 'que'],
#  ['tem', 'debater'],
#  ['que', 'proposta'],
#  ['que', 'tem'],
#  ['que', 'debater'],
#  ['que', 'eu'],
#  ['debater', 'tem'],
#  ['debater', 'que'],
#  ['debater', 'eu'],
#  ['debater', 'lamento'],
#  ['eu', 'que'],
#  ['eu', 'debater'],
#  ['eu', 'lamento'],
#  ['eu', 'porque'],
#  ['lamento', 'debater'],
#  ['lamento', 'eu'],
#  ['lamento', 'porque'],
#  ['lamento', 'se'],
#  ['porque', 'eu'],
#  ['porque', 'lamento'],
#  ['porque', 'se'],
#  ['porque', 'algum'],
#  ['se', 'lamento'],
#  ['se', 'porque'],
#  ['se', 'algum'],
#  ['se', 'quer'],
#  ['algum', 'porque'],
#  ['algum', 'se'],
#  ['algum', 'quer'],
#  ['algum', 'presid'],
#  ['quer', 'se'],
#  ['quer', 'algum'],
#  ['quer', 'presid'],
#  ['presid', 'algum'],
#  ['presid', 'quer'],
#  ['rt', 'bolsonaro'],
#  ['rt', 'promesa'],
#  ['bolsonaro', 'rt'],
#  ['bolsonaro', 'promesa'],
#  ['bolsonaro', 'certa'],
#  ['promesa', 'rt'],
#  ['promesa', 'bolsonaro'],
#  ['promesa', 'certa'],
#  ['promesa', 'de'],
#  ['certa', 'bolsonaro'],
#  ['certa', 'promesa'],
#  ['certa', 'de'],
#  ['certa', 'uma'],
#  ['de', 'promesa'],
#  ['de', 'certa'],
#  ['de', 'uma'],
#  ['de', 'crise'],
#  ['uma', 'certa'],
#  ['uma', 'de'],
#  ['uma', 'crise'],
#  ['uma', 'democraciasim'],
#  ['crise', 'de'],
#  ['crise', 'uma'],
#  ['crise', 'democraciasim'],
#  ['crise', 'htpstcoedgnyzx'],
#  ['democraciasim', 'uma'],
#  ['democraciasim', 'crise'],
#  ['democraciasim', 'htpstcoedgnyzx'],
#  ['htpstcoedgnyzx', 'crise'],
#  ['htpstcoedgnyzx', 'democraciasim'],
#  ['rt', 'cara'],
#  ['rt', 'bolsonaro'],
#  ['cara', 'rt'],
#  ['cara', 'bolsonaro'],
#  ['cara', 'chegou'],
#  ['bolsonaro', 'rt'],
#  ['bolsonaro', 'cara'],
#  ['bolsonaro', 'chegou'],
#  ['bolsonaro', 'h'],
#  ['chegou', 'cara'],
#  ['chegou', 'bolsonaro'],
#  ['chegou', 'h'],
#  ['chegou', 'menos'],
#  ['h', 'bolsonaro'],
#  ['h', 'chegou'],
#  ['h', 'menos'],
#  ['h', 'de'],
#  ['menos', 'chegou'],
#  ['menos', 'h'],
#  ['menos', 'de'],
#  ['menos', 'ms'],
#  ['de', 'h'],
#  ['de', 'menos'],
#  ['de', 'ms'],
#  ['de', 'milho'],
#  ['ms', 'menos'],
#  ['ms', 'de'],
#  ['ms', 'milho'],
#  ['ms', 'de'],
#  ['milho', 'de'],
#  ['milho', 'ms'],
#  ['milho', 'de'],
#  ['milho', 'inscritos'],
#  ['de', 'ms'],
#  ['de', 'milho'],
#  ['de', 'inscritos'],
#  ['de', 'youtube'],
#  ['inscritos', 'milho'],
#  ['inscritos', 'de'],
#  ['inscritos', 'youtube'],
#  ['inscritos', 'e'],
#  ['youtube', 'de'],
#  ['youtube', 'inscritos'],
#  ['youtube', 'e'],
#  ['youtube', 'j'],
#  ['e', 'inscritos'],
#  ['e', 'youtube'],
#  ['e', 'j'],
#  ['e', 'est'],
#  ['j', 'youtube'],
#  ['j', 'e'],
#  ['j', 'est'],
#  ['j', 'com'],
#  ['est', 'e'],
#  ['est', 'j'],
#  ['est', 'com'],
#  ['est', 'milho'],
#  ['com', 'j'],
#  ['com', 'est'],
#  ['com', 'milho'],
#  ['com', 'e'],
#  ['milho', 'est'],
#  ['milho', 'com'],
#  ['milho', 'e'],
#  ['milho', 'mil'],
#  ['e', 'com'],
#  ['e', 'milho'],
#  ['e', 'mil'],
#  ['e', 'inscritos'],
#  ['mil', 'milho'],
#  ['mil', 'e'],
#  ['mil', 'inscritos'],
#  ['inscritos', 'e'],
#  ['inscritos', 'mil'],
#  ['rt', 'proposta'],
#  ['rt', 'de'],
#  ['proposta', 'rt'],
#  ['proposta', 'de'],
#  ['proposta', 'bolsonaro'],
#  ['de', 'rt'],
#  ['de', 'proposta'],
#  ['de', 'bolsonaro'],
#  ['de', 'para'],
#  ['bolsonaro', 'proposta'],
#  ['bolsonaro', 'de'],
#  ['bolsonaro', 'para'],
#  ['bolsonaro', 'ensino'],
#  ['para', 'de'],
#  ['para', 'bolsonaro'],
#  ['para', 'ensino'],
#  ['para', 'distncia'],
#  ['ensino', 'bolsonaro'],
#  ['ensino', 'para'],
#  ['ensino', 'distncia'],
#  ['ensino', 'partir'],
#  ['distncia', 'para'],
#  ...]

# %%
for text in corpus:
    print(text)

df = pd.DataFrame(data, columns = ['input', 'label'])
# Out:
# rt falo como sapo de fora esas invenes de ataques por parte pesoal prpt para pintar esfaqueado bolsonaro como r
# rt viva nosa senhora aparecida pastor chutou imagem da santa e causou revolta pas edir macedo lder da
# rt bolsonaro fica em lugar com milhes de votos na frente revoltados com esa diferena os apoiadores de bo
# rt foi atacada foi agredida ia l nis atris tudo rinu k htpstcoraxqsoka
# iso brasil acima de tudo deus acima de todos brasilcombolsonaro
# rt boulos amigo hadad incitando uma multido invadir casa bolsonaro que deus proteja capito
# se vc lese plano de governo bolsonaro teria tanta certeza que teria comida htpstcosryrupyn
# rt daqui cem anos vai ter adolescente dizendo que bolsonaro foi de esquerda
# rt cara fica puto e xinga em latim mano htpstcogsdwiex
# rt auto crio tem manifestao contra presidencivel jair bolsonaro htpstcocrljxco
# rt chega nunca mais falo bem de bolsonaro depois disto aqui olhem q ele fez com um nordestino nordeste nordesteco
# bolsonaro diz que aceita realizar debate com hadad com condies htpstcoixrntkpa
# rt bolsonaro vai matar viado vai diminuir mulher vai bater em preto com prprias mos mas discurso de
# rt engrado n hadad quando bispo edir macedo apoiou pt voc reclamou agora que ele declara apoio ao jair bolsonaro
# rt governo de jair bolsonaro homem campo seja agronegcio ou da agricultura familiar ser valorizado bolsonaro
# rt sobre deputado jair bolsonaro quem tem proposta tem que debater eu lamento porque se algum quer presid
# rt bolsonaro promesa certa de uma crise democraciasim htpstcoedgnyzx
# rt cara bolsonaro chegou h menos de ms milho de inscritos youtube e j est com milho e mil inscritos
# rt proposta de bolsonaro para ensino distncia partir de anos de idade desconstri educao como conhecermos
# rt bolsonaro acaba de fazer um ao vivo facebok levantando novamente suspeitas de fraude nas urnas eletrnicas dise
# eu sou da poca que homem htero gostava de mulher agora eles tem teso e brigam pelo bolsonaro
# rt diz que eleitores de bolsonaro ofendem igreja catlica diz andrade qual rolou antes concli
# bolsonaro eu lamento esas agreses gostaria que elas parasem htpstcoiuegsiugm
# rt boulos amigo hadad incitando uma multido invadir casa bolsonaro que deus proteja capito
# rt jair bolsonaro tem qualificao para ser deputado quanto mais presidente deputados e ele sem sombra de
# rt provas de que bolsonaro patriota nem honesto muito menos cristo htpstcocndpcv
# rt em editorial wal stret journal afirmou os progresistas globais esto tendo um ataque de ansiedade por causa
# rt debata conosco os brasileiros que bolsonaro representa vc est fugindo de todas acusaes que lhe feitas aqui
# rt bolsonaro agradece apoio de doria e diz ter problema em encontrlo htpstcoyzskvhxk htpstcozoiearqr
# rt vou contar para vocs verdade sobre deputado jair bolsonaro htpstcohkmvxhpjf
# olha maria seu idalo k htpstcowgapgsnk
# rt hadad e bolsonaro tuitando um sobre outro parece aquele casal que terminou e ainda n superou trmino
# rt bolsonaro ama ulstra ulstra enfiava ratos vivos nas vaginas de mulheres torturadas e levava os filhos delas para vlas ca
# r
# rt deputado jair bolsonaro foge dos debates porque mentiroso como vocs podem ver nese vdeo compartilhe e envie p
# rt temos dias para dialogar com pesoas e desmistificar bolsonaro ele diz que de fora sistema ser ano
# esquerda costuma acreditar que basta apontar defeitos candidato adversrio para seu prprio htpstcobfesowt
# rt pau cu da mdia querem debate teria debate se tivesem enfiado uma faca de aougue na bariga bolsonaro
# rt cara recebe hadad htpstcoesbngfad
# rt janaina paschoal diz que abandona curso de violo se ele se mostrar musical htpstcoiwtzchgwf
# rt jos de abreu masacra regina duarte aps atriz declarar apoio bolsonaro e espalhar fakes news sobre governo pt h
# rt gente acabei de ficar sabendo se na urna eletrnica voc colocar ao invs de bolsonaro ganha nada men
# rt candidato ao governo rn carlos eduardo pdt declara seu apoio jair bolsonaro para presidente compartilhem htps
# olha pra mim ela insinua que bolsonaro mnimo um gay habitando armrio ou eu viajando
# rt cara recebe hadad htpstcoesbngfad
# rt na campanha pacifista pt companheiro boulos conclama invaso da casa de bolsonaro aquele que seu excolega de
# ento que est registrado l na cmara mentira mais de projetos e sendo que virou l htpstcosezesvtra
# rt bolsonaro agradece apoio de doria e diz ter problema em encontrlo htpstcoyzskvhxk htpstcozoiearqr
# rt foi atacada foi agredida ia l nis atris tudo rinu k htpstcoraxqsoka
# rt eu acho candidatura bolsonaro uma afronta inteligncia posvel que vo eleger um imbecil incapaz de debater e
# rt fukuyama mentor da margaret thatcher considerado deus liberalismo econmico falou que est preocupado com uma
# rt onde estava imprensa brasileira quando um esquerdista atropelou pesoas que apoiam bolsonaro htpstconslwaud
# rt proposta de bolsonaro para ensino distncia partir de anos de idade desconstri educao como conhecermos
# policial civil desmascara bolsonaro e seu comentrio sobre masacre de htpstcombuxszf via
# rt pesoal voc sabia que gente pode solicitar presena bolsonaro aos debates formalmente por aqui voc completa

# %%
df.head(10)
# Out:
#   input label
# 0    rt  falo
# 1    rt  como
# 2  falo    rt
# 3  falo  como
# 4  falo  sapo
# 5  como    rt
# 6  como  falo
# 7  como  sapo
# 8  como    de
# 9  sapo  falo

# %%
df.shape
# Out:
# (54550, 2)

# %%
word2int
# Out:
# {'desprezo': 0,
#  'francesa': 1,
#  'htpstcohkvblktqzi': 2,
#  'vtima': 3,
#  'htpstcobymubx': 4,
#  'patifaria': 5,
#  'sincero': 6,
#  'hofman': 7,
#  'acesores': 8,
#  'triste': 9,
#  'atacaram': 10,
#  'forja': 11,
#  'ap': 12,
#  'placa': 13,
#  'presidncia': 14,
#  'informar': 15,
#  'buro': 16,
#  'htpstcojrostl': 17,
#  'pegar': 18,
#  'falava': 19,
#  'histria': 20,
#  'prof': 21,
#  'comprova': 22,
#  'htpstcoarzmfnqgx': 23,
#  'fechamento': 24,
#  'nam': 25,
#  'encontrlo': 26,
#  'htpstcounlcoryp': 27,
#  'exce': 28,
#  'fodas': 29,
#  'apoiaram': 30,
#  'ofend': 31,
#  'outro': 32,
#  'ri': 33,
#  'insta': 34,
#  'gustavo': 35,
#  'wylys': 36,
#  'incentivo': 37,
#  'htpstcosezesvtra': 38,
#  'agredido': 39,
#  'bloquear': 40,
#  'influenciadores': 41,
#  'nazifascistas': 42,
#  'htpstcojnkzamvfera': 43,
#  'dito': 44,
#  'privatizad': 45,
#  'exorcismo': 46,
#  'cago': 47,
#  'ajudou': 48,
#  'aumentou': 49,
#  'xinga': 50,
#  'pesquisar': 51,
#  'nega': 52,
#  'bomes': 53,
#  'gostava': 54,
#  'tute': 55,
#  'declara': 56,
#  'pora': 57,
#  'familia': 58,
#  'podem': 59,
#  'ufrj': 60,
#  'htpstcoguxrfklq': 61,
#  'prncipe': 62,
#  'te': 63,
#  'jos': 64,
#  'tentativa': 65,
#  'fala': 66,
#  'cuspidor': 67,
#  'mato': 68,
#  'achando': 69,
#  'gay': 70,
#  'viva': 71,
#  'sistema': 72,
#  'volta': 73,
#  'preconceituoso': 74,
#  'eduardo': 75,
#  'financeiro': 76,
#  'barbaridades': 77,
#  'certo': 78,
#  'letras': 79,
#  'ns': 80,
#  'mentor': 81,
#  'htpstcomayqteumy': 82,
#  'htpstcowemkigr': 83,
#  'alerta': 84,
#  'preso': 85,
#  'favelados': 86,
#  'horor': 87,
#  'valeu': 88,
#  'rabe': 89,
#  'htpstcospziqte': 90,
#  'prpria': 91,
#  'pele': 92,
#  'homo': 93,
#  'balanando': 94,
#  'acreditar': 95,
#  'aprendeu': 96,
#  'vermelha': 97,
#  'criou': 98,
#  'urgncia': 99,
#  'por': 100,
#  'campanh': 101,
#  'maranho': 102,
#  'debata': 103,
#  'deputados': 104,
#  'rouanet': 105,
#  'responsveis': 106,
#  'suspeio': 107,
#  'declarou': 108,
#  'nmer': 109,
#  'cadastradas': 110,
#  'htpstcozrbexygwp': 111,
#  'grupos': 112,
#  'oriente': 113,
#  'htpstcocrljxco': 114,
#  'juza': 115,
#  'responder': 116,
#  'familiares': 117,
#  'pslpr': 118,
#  'revoltados': 119,
#  'fraude': 120,
#  'manuela': 121,
#  'bol': 122,
#  'meu': 123,
#  'mario': 124,
#  'crianas': 125,
#  'convidar': 126,
#  'realmente': 127,
#  'eua': 128,
#  'direito': 129,
#  'que': 130,
#  'brasileiros': 131,
#  'bote': 132,
#  'proteger': 133,
#  'panteras': 134,
#  'minas': 135,
#  'fernando': 136,
#  'serve': 137,
#  'debatidas': 138,
#  'htpstcolrmxtjvg': 139,
#  'htpstconehtrcdtb': 140,
#  'incitar': 141,
#  'dirio': 142,
#  'seguida': 143,
#  'conheo': 144,
#  'viver': 145,
#  'cotas': 146,
#  'apelido': 147,
#  'puta': 148,
#  'apanhando': 149,
#  'lula': 150,
#  'citada': 151,
#  'htpstcohkmvxhpjf': 152,
#  'eae': 153,
#  'ascenso': 154,
#  'esprito': 155,
#  'apoiadora': 156,
#  'merval': 157,
#  'insinua': 158,
#  'invaso': 159,
#  'alckmin': 160,
#  'qualquer': 161,
#  'htpstcogkqxoltu': 162,
#  'segura': 163,
#  'ensina': 164,
#  'comunistas': 165,
#  'restos': 166,
#  'motorista': 167,
#  'agreso': 168,
#  'funcionrios': 169,
#  'democraciasim': 170,
#  'arumar': 171,
#  'reduzir': 172,
#  'bate': 173,
#  'produtora': 174,
#  'externas': 175,
#  'faca': 176,
#  'estoucombols': 177,
#  'relator': 178,
#  'muda': 179,
#  'idealizao': 180,
#  'publicao': 181,
#  'regininha': 182,
#  'escolar': 183,
#  'htpstcoayzjtuwqco': 184,
#  'aborto': 185,
#  'rio': 186,
#  'htpstcovofosk': 187,
#  'ht': 188,
#  'varias': 189,
#  'saia': 190,
#  'atrs': 191,
#  'htpstcozjgqomdv': 192,
#  'esforo': 193,
#  'ater': 194,
#  'foz': 195,
#  'quero': 196,
#  'base': 197,
#  'eleitoral': 198,
#  'escolheu': 199,
#  'mtico': 200,
#  'homofbico': 201,
#  'cumprir': 202,
#  'menor': 203,
#  'catlica': 204,
#  'calnias': 205,
#  'lgbts': 206,
#  'qaeda': 207,
#  'enquanto': 208,
#  'anotem': 209,
#  'homofobia': 210,
#  'adicionei': 211,
#  'branda': 212,
#  'crists': 213,
#  'tivese': 214,
#  'htpstcoqjyfksli': 215,
#  'latino': 216,
#  'destinou': 217,
#  'htpstcotnmprgr': 218,
#  'teve': 219,
#  'feia': 220,
#  'longas': 221,
#  'safadeza': 222,
#  'negros': 223,
#  'bastidores': 224,
#  'htp': 225,
#  'hezbolah': 226,
#  'desistiram': 227,
#  'falsas': 228,
#  'vaiado': 229,
#  'ajudar': 230,
#  'mesias': 231,
#  'sangue': 232,
#  'ofendem': 233,
#  'vencer': 234,
#  'esto': 235,
#  'fv': 236,
#  'sente': 237,
#  'polticas': 238,
#  'querer': 239,
#  'vitoriosa': 240,
#  'fraco': 241,
#  'longo': 242,
#  'condies': 243,
#  'aparece': 244,
#  'curta': 245,
#  'acontecendo': 246,
#  'gravou': 247,
#  'infinitamente': 248,
#  'aliana': 249,
#  'universidade': 250,
#  'manipulao': 251,
#  'chamar': 252,
#  'htpstcozsmzmwht': 253,
#  'htpstcoyhesukvbet': 254,
#  'falsidad': 255,
#  'defendeu': 256,
#  'ouvir': 257,
#  'baixou': 258,
#  'htpstcotnzeilqfr': 259,
#  'marcel': 260,
#  'htpstcoitrwtvf': 261,
#  'prev': 262,
#  'boas': 263,
#  'pichao': 264,
#  'mauricio': 265,
#  'devoto': 266,
#  'htpstcozrvtalefh': 267,
#  'amarelando': 268,
#  'anlise': 269,
#  'banido': 270,
#  'uns': 271,
#  'motivos': 272,
#  'ofendendo': 273,
#  'teria': 274,
#  'vestia': 275,
#  'afinal': 276,
#  'bar': 277,
#  'liked': 278,
#  'minhas': 279,
#  'subjugar': 280,
#  'parlamentares': 281,
#  'sinal': 282,
#  'htpstcongujzpny': 283,
#  'maquinetas': 284,
#  'revela': 285,
#  'ah': 286,
#  'comunho': 287,
#  'eses': 288,
#  'noite': 289,
#  'direita': 290,
#  'mercado': 291,
#  'misgino': 292,
#  'htpstcodeafma': 293,
#  'balada': 294,
#  'htpstcordsmzroxs': 295,
#  'prol': 296,
#  'espalhadas': 297,
#  'bancada': 298,
#  'htpstcoyukpactd': 299,
#  'apelando': 300,
#  'nmero': 301,
#  'solicitar': 302,
#  'seja': 303,
#  'htpstcozkqlqmnaq': 304,
#  'moa': 305,
#  'manifestaes': 306,
#  'nazis': 307,
#  'arquivado': 308,
#  'repete': 309,
#  'ou': 310,
#  'primeiros': 311,
#  'prpt': 312,
#  'algum': 313,
#  'derotou': 314,
#  'imagem': 315,
#  'militantes': 316,
#  'postura': 317,
#  'ele': 318,
#  'barlo': 319,
#  'diretamente': 320,
#  'asumir': 321,
#  'gigantes': 322,
#  'registro': 323,
#  'repercuso': 324,
#  'duro': 325,
#  'gt': 326,
#  'tava': 327,
#  'htpstcojoqimck': 328,
#  'mintam': 329,
#  'baseado': 330,
#  'logo': 331,
#  'superou': 332,
#  'devem': 333,
#  'incitaram': 334,
#  'htpstcoifhknwlt': 335,
#  'santa': 336,
#  'perguntas': 337,
#  'controlar': 338,
#  'cu': 339,
#  'provar': 340,
#  'condenado': 341,
#  'liberalismo': 342,
#  'htpstcot': 343,
#  'ulstra': 344,
#  'fujam': 345,
#  'derubou': 346,
#  'partidrio': 347,
#  'htpstcoegcgdie': 348,
#  'esquadres': 349,
#  'ansiedade': 350,
#  'htpstcoijdkpbu': 351,
#  'tema': 352,
#  'internacional': 353,
#  'extremista': 354,
#  'pos': 355,
#  'piada': 356,
#  'htpstcoulysdskuk': 357,
#  'helena': 358,
#  'sera': 359,
#  'contedo': 360,
#  'htpstcoquhgkighj': 361,
#  'feministas': 362,
#  'anunciar': 363,
#  'futuro': 364,
#  'sofre': 365,
#  'prometeu': 366,
#  'preciso': 367,
#  'veja': 368,
#  'entendam': 369,
#  'dio': 370,
#  'degradao': 371,
#  'htpstcoytaixcugv': 372,
#  'obrigada': 373,
#  'oi': 374,
#  'htpstcoxypspjegq': 375,
#  'post': 376,
#  'argemiro': 377,
#  'cearense': 378,
#  'rt': 379,
#  'pela': 380,
#  'seria': 381,
#  'matria': 382,
#  'reforma': 383,
#  'top': 384,
#  'agresor': 385,
#  'galera': 386,
#  'nem': 387,
#  'leandro': 388,
#  'lixo': 389,
#  'federal': 390,
#  'htpstcobklvintl': 391,
#  'recebeu': 392,
#  'gosta': 393,
#  'enxurada': 394,
#  'ocupao': 395,
#  'chamado': 396,
#  'numero': 397,
#  'discordncias': 398,
#  'diseram': 399,
#  'cristos': 400,
#  'atores': 401,
#  'ler': 402,
#  'rs': 403,
#  'culpa': 404,
#  'tomam': 405,
#  'motivo': 406,
#  'perceber': 407,
#  'levava': 408,
#  'psimo': 409,
#  'negocio': 410,
#  'minutos': 411,
#  'gerais': 412,
#  'nese': 413,
#  'vem': 414,
#  'role': 415,
#  'civilizatrioele': 416,
#  'htpstcopuoc': 417,
#  'apareceu': 418,
#  'htpstcozfryepmci': 419,
#  'fukuyama': 420,
#  'acha': 421,
#  'mentiras': 422,
#  'canas': 423,
#  'ambienta': 424,
#  'bonosauro': 425,
#  'htpstcojveptynp': 426,
#  'registrado': 427,
#  'pq': 428,
#  'tem': 429,
#  'est': 430,
#  'func': 431,
#  'tanta': 432,
#  'ultraje': 433,
#  'bandeirantes': 434,
#  'polmica': 435,
#  'praia': 436,
#  'htpstcojnopfonfvo': 437,
#  'piru': 438,
#  'agresivo': 439,
#  'senhor': 440,
#  'new': 441,
#  'elegeu': 442,
#  'isto': 443,
#  'dedinho': 444,
#  'dia': 445,
#  'colocar': 446,
#  'resolvi': 447,
#  'foto': 448,
#  'circule': 449,
#  'pedindo': 450,
#  'htpstcodbyxjnaxmqfera': 451,
#  'revistas': 452,
#  'ameas': 453,
#  'dantesco': 454,
#  'retuitando': 455,
#  'punida': 456,
#  'juntos': 457,
#  'olha': 458,
#  'deparo': 459,
#  'movimento': 460,
#  'fico': 461,
#  'esta': 462,
#  'blocks': 463,
#  'waldvogel': 464,
#  'tentam': 465,
#  'admite': 466,
#  'usando': 467,
#  'candidatu': 468,
#  'emprender': 469,
#  'candidatura': 470,
#  'curtindo': 471,
#  'gostei': 472,
#  'este': 473,
#  'conhecemos': 474,
#  'direcionam': 475,
#  'joga': 476,
#  'gra': 477,
#  'tuitando': 478,
#  'bero': 479,
#  'extremadireita': 480,
#  'fazermos': 481,
#  'htpstcoiuegsiugm': 482,
#  'humanas': 483,
#  'termina': 484,
#  'pouquinho': 485,
#  'votando': 486,
#  'hadad': 487,
#  'nogu': 488,
#  'grava': 489,
#  'boicotar': 490,
#  'tnc': 491,
#  'sustica': 492,
#  'manca': 493,
#  'tucano': 494,
#  'escrita': 495,
#  'pensam': 496,
#  'pretende': 497,
#  'ningum': 498,
#  'documento': 499,
#  'chegaram': 500,
#  'fcil': 501,
#  'incapaz': 502,
#  'htpstcotir': 503,
#  'br': 504,
#  'caro': 505,
#  'cultura': 506,
#  'entanto': 507,
#  'problema': 508,
#  'votou': 509,
#  'levantando': 510,
#  'atendimento': 511,
#  'promesa': 512,
#  'atacar': 513,
#  'ela': 514,
#  'aps': 515,
#  'numa': 516,
#  'mec': 517,
#  'onyx': 518,
#  'htpstcoyngukfp': 519,
#  'htpstconreojyorg': 520,
#  'cmica': 521,
#  'mt': 522,
#  'informao': 523,
#  'governo': 524,
#  'adivinha': 525,
#  'caruagem': 526,
#  'creio': 527,
#  'catequizavam': 528,
#  'desmente': 529,
#  'nosa': 530,
#  'coruptos': 531,
#  'invs': 532,
#  'amiga': 533,
#  'fuma': 534,
#  'temer': 535,
#  'estude': 536,
#  'demais': 537,
#  'atestado': 538,
#  'pastores': 539,
#  'facebok': 540,
#  'votar': 541,
#  'danos': 542,
#  'candidato': 543,
#  'internet': 544,
#  'armadas': 545,
#  'namorado': 546,
#  'tais': 547,
#  'provel': 548,
#  'po': 549,
#  'crise': 550,
#  'conto': 551,
#  'atacando': 552,
#  'vote': 553,
#  'propostas': 554,
#  'qu': 555,
#  'vi': 556,
#  'respeito': 557,
#  'socialismo': 558,
#  'estuprada': 559,
#  'humanamente': 560,
#  'htpstcoymebuqrk': 561,
#  'racista': 562,
#  'htpstcovtvgqguhv': 563,
#  'toma': 564,
#  'deus': 565,
#  'repblica': 566,
#  'jogar': 567,
#  'aliados': 568,
#  'stf': 569,
#  'htpstcoidpirgywk': 570,
#  'batem': 571,
#  'lido': 572,
#  'elas': 573,
#  'estar': 574,
#  'bolsa': 575,
#  'htpstcovpv': 576,
#  'duas': 577,
#  'projeto': 578,
#  'petrolina': 579,
#  'gil': 580,
#  'htpstcofruyk': 581,
#  'profisional': 582,
#  'sou': 583,
#  'flagrado': 584,
#  'htpstcogrvxmjwq': 585,
#  'reafirmou': 586,
#  'tempo': 587,
#  'muito': 588,
#  'ouvi': 589,
#  'orgulho': 590,
#  'amigo': 591,
#  'defensor': 592,
#  'gnt': 593,
#  'violenta': 594,
#  'conversar': 595,
#  'participei': 596,
#  'divulgou': 597,
#  'indiretas': 598,
#  'desmontar': 599,
#  'dica': 600,
#  'todynho': 601,
#  'vrias': 602,
#  'anular': 603,
#  'palestra': 604,
#  'globo': 605,
#  'mortos': 606,
#  'color': 607,
#  'com': 608,
#  'presidencivel': 609,
#  'cqc': 610,
#  'anjo': 611,
#  'eita': 612,
#  'presid': 613,
#  'programa': 614,
#  'ser': 615,
#  'corupta': 616,
#  'waters': 617,
#  'htpstcopmvcd': 618,
#  'gastos': 619,
#  'witzel': 620,
#  'bertoche': 621,
#  'chegada': 622,
#  'vermelho': 623,
#  'delegado': 624,
#  'psl': 625,
#  'bernardo': 626,
#  'acaba': 627,
#  'comprado': 628,
#  'revolta': 629,
#  'capim': 630,
#  'crime': 631,
#  'htpstcoifefcdy': 632,
#  'nesa': 633,
#  'fontes': 634,
#  'gran': 635,
#  'ntido': 636,
#  'pregado': 637,
#  'casal': 638,
#  'escreveu': 639,
#  'h': 640,
#  'fraquejada': 641,
#  'desagradveis': 642,
#  'vagabundo': 643,
#  'audincias': 644,
#  'van': 645,
#  'val': 646,
#  'mel': 647,
#  'dutra': 648,
#  'dise': 649,
#  'obcecado': 650,
#  'pisa': 651,
#  'criticada': 652,
#  'rihan': 653,
#  'mundo': 654,
#  'residncia': 655,
#  'caralho': 656,
#  'reas': 657,
#  'momento': 658,
#  'mulher': 659,
#  'falar': 660,
#  'contincia': 661,
#  'ento': 662,
#  'feminina': 663,
#  'votam': 664,
#  'cota': 665,
#  'posam': 666,
#  'mortes': 667,
#  'bato': 668,
#  'titio': 669,
#  'fundamentalismo': 670,
#  'envolvendo': 671,
#  'costuma': 672,
#  'despreparado': 673,
#  'catlicos': 674,
#  'estatais': 675,
#  'canta': 676,
#  'fazo': 677,
#  'questo': 678,
#  'disto': 679,
#  'confirma': 680,
#  'come': 681,
#  'nordeste': 682,
#  'priso': 683,
#  'colunista': 684,
#  'interferindo': 685,
#  'incitando': 686,
#  'subscreveram': 687,
#  'direto': 688,
#  'maneira': 689,
#  'recado': 690,
#  'chavez': 691,
#  'apoiam': 692,
#  'playlist': 693,
#  'matou': 694,
#  'rachando': 695,
#  'fora': 696,
#  'canalha': 697,
#  'acham': 698,
#  'recusado': 699,
#  'morte': 700,
#  'htpstcoyzskvhxk': 701,
#  'cmara': 702,
#  'dcada': 703,
#  'hein': 704,
#  'vociferar': 705,
#  'oq': 706,
#  'espalhaele': 707,
#  'sapata': 708,
#  'sorte': 709,
#  'htpstcososhrc': 710,
#  'apenas': 711,
#  'sabino': 712,
#  'deixar': 713,
#  'parem': 714,
#  'htpstconslwaud': 715,
#  'maior': 716,
#  'vlas': 717,
#  'soros': 718,
#  'petrobras': 719,
#  'peo': 720,
#  'htpstcoflwtc': 721,
#  'trabalha': 722,
#  'renunciaptqueocirovence': 723,
#  'legitimando': 724,
#  'famlia': 725,
#  'acabando': 726,
#  'molengas': 727,
#  'urgente': 728,
#  'uma': 729,
#  'valor': 730,
#  'apoiar': 731,
#  'nenhuma': 732,
#  'populaodia': 733,
#  'postou': 734,
#  'compartilhado': 735,
#  'zapzap': 736,
#  'olhe': 737,
#  'cabra': 738,
#  'morer': 739,
#  'maravilha': 740,
#  'esfaqueou': 741,
#  'em': 742,
#  'vey': 743,
#  'asasina': 744,
#  'distribua': 745,
#  'htpstcoyzfqzfwhek': 746,
#  'competindo': 747,
#  'estarei': 748,
#  'parasem': 749,
#  'circulao': 750,
#  'mandando': 751,
#  'tribuna': 752,
#  'venezuela': 753,
#  'mandado': 754,
#  'como': 755,
#  'neutralidade': 756,
#  'hadadlula': 757,
#  'envie': 758,
#  'ditadura': 759,
#  'fdp': 760,
#  'liberar': 761,
#  'pedido': 762,
#  'lgbt': 763,
#  'grave': 764,
#  'acusaes': 765,
#  'admiro': 766,
#  'negras': 767,
#  'risco': 768,
#  'recordtv': 769,
#  'expert': 770,
#  'desde': 771,
#  'htpstc': 772,
#  'unio': 773,
#  'percebeu': 774,
#  'htpstcoxkidbydfoj': 775,
#  'fhc': 776,
#  'htpstcohysltdcty': 777,
#  'primo': 778,
#  'jovens': 779,
#  'twi': 780,
#  'mudar': 781,
#  'htpstcovgemcyju': 782,
#  'continuar': 783,
#  'ideali': 784,
#  'mortais': 785,
#  'intransponveis': 786,
#  'plano': 787,
#  'verdade': 788,
#  'psiquitrico': 789,
#  'eram': 790,
#  'imperdvel': 791,
#  'material': 792,
#  'sem': 793,
#  'htpstcovfqydpgx': 794,
#  'prefeito': 795,
#  'fo': 796,
#  'quan': 797,
#  'esquerda': 798,
#  'juiz': 799,
#  'deses': 800,
#  'lance': 801,
#  'hahahahahaha': 802,
#  'tendo': 803,
#  'htpstcokfgjewgvk': 804,
#  'lembramse': 805,
#  'votao': 806,
#  'tu': 807,
#  'algo': 808,
#  'pacifista': 809,
#  'confiar': 810,
#  'htpstcodiecvkp': 811,
#  'sai': 812,
#  'leitura': 813,
#  'diagnstico': 814,
#  'peso': 815,
#  'roubar': 816,
#  'madona': 817,
#  'todos': 818,
#  'visitou': 819,
#  'fundo': 820,
#  'capito': 821,
#  'maurcio': 822,
#  'portal': 823,
#  'pior': 824,
#  'htpstcogsoeqpefd': 825,
#  'htpstcoypbkyfdla': 826,
#  'aos': 827,
#  'profisiona': 828,
#  'formalmente': 829,
#  'dizer': 830,
#  'atacarem': 831,
#  'aceita': 832,
#  'novamente': 833,
#  'hatem': 834,
#  'ausncia': 835,
#  'histrias': 836,
#  'criminosas': 837,
#  'aqui': 838,
#  'vou': 839,
#  'surgiu': 840,
#  'ruas': 841,
#  'sergio': 842,
#  'povo': 843,
#  'tentavam': 844,
#  'esquecem': 845,
#  'poucos': 846,
#  'minha': 847,
#  'poema': 848,
#  'mein': 849,
#  'ajuda': 850,
#  'mentira': 851,
#  'eletrnicas': 852,
#  'pai': 853,
#  'ferenho': 854,
#  'copia': 855,
#  'expe': 856,
#  'spc': 857,
#  'ancio': 858,
#  'vez': 859,
#  'atos': 860,
#  'norte': 861,
#  'apoio': 862,
#  'prova': 863,
#  'opositores': 864,
#  'logotipo': 865,
#  'estudo': 866,
#  'recebido': 867,
#  'lucro': 868,
#  'nada': 869,
#  'chamando': 870,
#  'propor': 871,
#  'mbl': 872,
#  'canalhice': 873,
#  'tirar': 874,
#  'htpstcojblgf': 875,
#  'caras': 876,
#  'htpstcosoudxyw': 877,
#  'mandou': 878,
#  'voltou': 879,
#  'recentemente': 880,
#  'umas': 881,
#  'universal': 882,
#  'pesquisa': 883,
#  'soltou': 884,
#  'htpstcowaorheyal': 885,
#  'htpstcovcsyxmeu': 886,
#  'feliz': 887,
#  'chamam': 888,
#  'suja': 889,
#  'petistada': 890,
#  'htpstcomvxlwzxsr': 891,
#  'beijo': 892,
#  'j': 893,
#  'pede': 894,
#  'cima': 895,
#  'foro': 896,
#  'ahaha': 897,
#  'fosem': 898,
#  'aceitem': 899,
#  'extra': 900,
#  'rolou': 901,
#  'hoje': 902,
#  'leis': 903,
#  'retirados': 904,
#  'n': 905,
#  'luta': 906,
#  'maiso': 907,
#  'bolsonarismo': 908,
#  'riscada': 909,
#  'htpstcopcbxv': 910,
#  'desa': 911,
#  'adianta': 912,
#  'margaret': 913,
#  'sur': 914,
#  'poupar': 915,
#  'recebe': 916,
#  'contar': 917,
#  'charlatanismo': 918,
#  'jesus': 919,
#  'htpstcoqvqknqo': 920,
#  'nordestinos': 921,
#  'sofrimento': 922,
#  'movi': 923,
#  'estampadas': 924,
#  'ambiente': 925,
#  'atraso': 926,
#  'coragem': 927,
#  'da': 928,
#  'whatsap': 929,
#  'htpstcokhlefjqbcg': 930,
#  'twet': 931,
#  'roger': 932,
#  'conseguiu': 933,
#  'meio': 934,
#  'trabalho': 935,
#  'cortar': 936,
#  'inacreditvel': 937,
#  'altos': 938,
#  'barulho': 939,
#  'pasou': 940,
#  'htpstcorlaqwzc': 941,
#  'tenho': 942,
#  'solues': 943,
#  'papo': 944,
#  'arependido': 945,
#  'htpstcojqcwutqes': 946,
#  'peido': 947,
#  'nas': 948,
#  'wtf': 949,
#  'bo': 950,
#  'biro': 951,
#  'organizar': 952,
#  'metendo': 953,
#  'bandido': 954,
#  'amor': 955,
#  'corupto': 956,
#  'falam': 957,
#  'htpstcodftnyjtpgf': 958,
#  'torturadocrucificado': 959,
#  'aceitar': 960,
#  'direitinho': 961,
#  'bolson': 962,
#  'htpstcogsdwiex': 963,
#  'vena': 964,
#  'cad': 965,
#  'enforca': 966,
#  'hipocrisia': 967,
#  'minorias': 968,
#  'ca': 969,
#  'lutar': 970,
#  'comear': 971,
#  'htpstcoikdqknqoy': 972,
#  'antagonista': 973,
#  'htpstcotkxbatlh': 974,
#  'htpstcowkpfgadc': 975,
#  'pres': 976,
#  'esque': 977,
#  'ira': 978,
#  'fez': 979,
#  'elogia': 980,
#  'ficam': 981,
#  'igreja': 982,
#  'bolso': 983,
#  'futuros': 984,
#  'vivo': 985,
#  'retirar': 986,
#  'reclamou': 987,
#  'pariu': 988,
#  'testa': 989,
#  'htpstcojtlzjk': 990,
#  'sim': 991,
#  'entretan': 992,
#  'fonte': 993,
#  'eleies': 994,
#  'cut': 995,
#  'ask': 996,
#  'manda': 997,
#  'raciocnio': 998,
#  'dias': 999,
#  ...}

# %%
ONE_HOT_DIM = len(words)

# function to convert numbers to one hot vectors
def to_one_hot_encoding(data_point_index):
    one_hot_encoding = np.zeros(ONE_HOT_DIM)
    one_hot_encoding[data_point_index] = 1
    return one_hot_encoding

X = [] # input word
Y = [] # target word

for x, y in zip(df['input'], df['label']):
    X.append(to_one_hot_encoding(word2int[ x ]))
    Y.append(to_one_hot_encoding(word2int[ y ]))

# convert them to numpy arrays
X_train = np.asarray(X)
Y_train = np.asarray(Y)

# making placeholders for X_train and Y_train
x = tf.placeholder(tf.float32, shape=(None, ONE_HOT_DIM))
y_label = tf.placeholder(tf.float32, shape=(None, ONE_HOT_DIM))

# word embedding will be 2 dimension for 2d visualization
EMBEDDING_DIM = 2 

# hidden layer: which represents word vector eventually
W1 = tf.Variable(tf.random_normal([ONE_HOT_DIM, EMBEDDING_DIM]))
b1 = tf.Variable(tf.random_normal([1])) #bias
hidden_layer = tf.add(tf.matmul(x,W1), b1)

# output layer
W2 = tf.Variable(tf.random_normal([EMBEDDING_DIM, ONE_HOT_DIM]))
b2 = tf.Variable(tf.random_normal([1]))
prediction = tf.nn.softmax(tf.add( tf.matmul(hidden_layer, W2), b2))

# loss function: cross entropy
loss = tf.reduce_mean(-tf.reduce_sum(y_label * tf.log(prediction), axis=[1]))

# training operation
train_op = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

# %%
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init) 

iteration = 20000
for i in range(iteration):
    # input is X_train which is one hot encoded word
    # label is Y_train which is one hot encoded neighbor word
    sess.run(train_op, feed_dict={x: X_train, y_label: Y_train})
    if i % 3000 == 0:
        print('iteration '+str(i)+' loss is : ', sess.run(loss, feed_dict={x: X_train, y_label: Y_train}))

# %%
# Now the hidden layer (W1 + b1) is actually the word look up table
vectors = sess.run(W1 + b1)
print(vectors)

# %%
w2v_df = pd.DataFrame(vectors, columns = ['x1', 'x2'])
w2v_df['word'] = words
w2v_df = w2v_df[['word', 'x1', 'x2']]
w2v_df

# %%
fig, ax = plt.subplots()

for word, x1, x2 in zip(w2v_df['word'], w2v_df['x1'], w2v_df['x2']):
    ax.annotate(word, (x1,x2 ))
    
PADDING = 1.0
x_axis_min = np.amin(vectors, axis=0)[0] - PADDING
y_axis_min = np.amin(vectors, axis=0)[1] - PADDING
x_axis_max = np.amax(vectors, axis=0)[0] + PADDING
y_axis_max = np.amax(vectors, axis=0)[1] + PADDING
 
plt.xlim(x_axis_min,x_axis_max)
plt.ylim(y_axis_min,y_axis_max)
plt.rcParams["figure.figsize"] = (10,10)

plt.show()
